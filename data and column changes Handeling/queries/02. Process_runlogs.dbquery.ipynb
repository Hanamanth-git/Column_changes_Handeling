-- %%
create table if not exists pricing_data.process_run_logs.pipeline_process_control(
  Process_file_name string,
  Process_datetime timestamp,
  Process_status string,
  logs_timestamp timestamp
)
