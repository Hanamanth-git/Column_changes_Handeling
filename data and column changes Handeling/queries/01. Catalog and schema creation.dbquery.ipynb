-- %%
create catalog if not exists pricing_data;

create schema if not exists pricing_data.deltaLake;

create schema if not exists pricing_data.bronze;

create schema if not exists pricing_data.silver;

create schema if not exists pricing_data.gold;

create schema if not exists pricing_data.process_run_logs;

create volume if not exists pricing_data.deltaLake.landing;

create volume if not exists pricing_data.deltaLake.quarntine;

create volume if not exists pricing_data.deltaLake.bronze;
